# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('results.csv')

df['Throughput'] = df['Bank region size (B)'] / df['Time (s)']

sns.lineplot(
    data=df,
    x='Bank region size (B)',
    y='Throughput'
)
plt.xscale('log')
df
# Out:
#      Bank region size (B)  Trial  Time (s)    Throughput
# 0                    1024      0  0.001746  5.864129e+05
# 1                    1024      1  0.000032  3.193812e+07
# 2                    1024      2  0.000031  3.302161e+07
# 3                    1024      3  0.000045  2.281894e+07
# 4                    1024      4  0.000021  4.972322e+07
# ..                    ...    ...       ...           ...
# 155            1073741824      5  0.183370  5.855602e+09
# 156            1073741824      6  0.183606  5.848076e+09
# 157            1073741824      7  0.183216  5.860524e+09
# 158            1073741824      8  0.183340  5.856561e+09
# 159            1073741824      9  0.183250  5.859437e+09
#
# [160 rows x 4 columns]
